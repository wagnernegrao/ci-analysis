# %%
import pandas as pd

# %%
file = 'travistorrent_11_1_2017.csv'
chunksize = 1000000

# %%
for dataset in pd.read_csv(file, engine='c', chunksize=chunksize):
    process(dataset)
# Out:
# /home/wagner/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3,6,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ----------------------------------------------------------
# NameError                Traceback (most recent call last)
# <ipython-input-3-92e1eb900a9e> in <module>()
#       1 for dataset in pd.read_csv(file, engine='c', chunksize=chunksize):
# ----> 2     process(dataset)
#
# NameError: name 'process' is not defined

# %%
#dataset = pd.read_csv('travistorrent_11_1_2017.csv',sep=',', engine='c', nrows=3000000, na_values=str, keep_default_na = bool, encoding='utf-8')
# nrows=1000000
'''
Signature:
    sep - separa por virgula
    nrows - limite de linhas lidas
    encoding - tipo de caracter
    engine - Mecanismo do analisador
    na_values - procura os padrões na|nan como str
    keep_default_na - define como nan os padroes econtrados em na_values
    
'''
# Out:
# '\nSignature:\n    sep - separa por virgula\n    nrows - limite de linhas lidas\n    encoding - tipo de caracter\n    engine - Mecanismo do analisador\n    na_values - procura os padrões na|nan como str\n    keep_default_na - define como nan os padroes econtrados em na_values\n    \n'

# %% [markdown]
# <font size=4/>
#    * Elimia as colunas não utilizadas

# %%
# Eliminando colunas
dataset.drop([  'gh_diff_files_added',
                'gh_commits_in_push',
                'gh_diff_files_deleted',
                'gh_diff_files_modified',
                'gh_diff_tests_added',
                'gh_diff_tests_deleted',
                'gh_diff_src_files',
                'gh_diff_doc_files',
                'gh_diff_other_files',
                'gh_sloc',
                'gh_test_lines_per_kloc',
                'gh_test_cases_per_kloc',
            
                'tr_duration',
                'tr_log_lan',
                'tr_log_num_tests_run',
                'tr_log_setup_time',
                'tr_log_analyzer',
                'tr_log_frameworks',
                'tr_log_bool_tests_ran',
                'tr_log_bool_tests_failed',
                'tr_log_tests_failed',
                'tr_log_testduration',
                'tr_log_buildduration'], axis=1, inplace=True)

# %%
def categorizaPush(valor):
    if(valor < 20):
        return 0

# %% [markdown]
# <font size=4/>
#    * Filtra o projeto

# %%
df_ruby = dataset.loc[dataset['gh_project_name']=='rails/rails'] # Filtro penas o projeto rails/rails

# %%
ruby_master = df_ruby.loc[df_ruby['git_branch']== 'master']

# %%
ruby_master
# Out:
#         tr_build_id gh_project_name  gh_is_pr gh_pr_created_at  \
# 15           106176     rails/rails     False              NaN
# 16           106176     rails/rails     False              NaN
# 17           106176     rails/rails     False              NaN
# 18           106176     rails/rails     False              NaN
# 19           106176     rails/rails     False              NaN
# 20           106176     rails/rails     False              NaN
# 21           106176     rails/rails     False              NaN
# 22           106176     rails/rails     False              NaN
# 23           106176     rails/rails     False              NaN
# 24           106176     rails/rails     False              NaN
# 25           106176     rails/rails     False              NaN
# 26           106176     rails/rails     False              NaN
# 27           106176     rails/rails     False              NaN
# 28           106176     rails/rails     False              NaN
# 29           106176     rails/rails     False              NaN
# 181          108038     rails/rails     False              NaN
# 182          108038     rails/rails     False              NaN
# 183          108038     rails/rails     False              NaN
# 184          108038     rails/rails     False              NaN
# 185          108038     rails/rails     False              NaN
# 186          108038     rails/rails     False              NaN
# 187          108038     rails/rails     False              NaN
# 188          108038     rails/rails     False              NaN
# 189          108038     rails/rails     False              NaN
# 190          108038     rails/rails     False              NaN
# 191          108038     rails/rails     False              NaN
# 192          108038     rails/rails     False              NaN
# 193          108038     rails/rails     False              NaN
# 194          108038     rails/rails     False              NaN
# 195          108038     rails/rails     False              NaN
# ...             ...             ...       ...              ...
# 999925     16114498     rails/rails     False              NaN
# 999926     16114498     rails/rails     False              NaN
# 999927     16114498     rails/rails     False              NaN
# 999928     16114498     rails/rails     False              NaN
# 999929     16114498     rails/rails     False              NaN
# 999930     16114498     rails/rails     False              NaN
# 999931     16114498     rails/rails     False              NaN
# 999932     16114498     rails/rails     False              NaN
# 999933     16114498     rails/rails     False              NaN
# 999934     16114498     rails/rails     False              NaN
# 999935     16114498     rails/rails     False              NaN
# 999936     16114498     rails/rails     False              NaN
# 999937     16114498     rails/rails     False              NaN
# 999938     16114498     rails/rails     False              NaN
# 999939     16114498     rails/rails     False              NaN
# 999940     16114498     rails/rails     False              NaN
# 999941     16114498     rails/rails     False              NaN
# 999942     16114498     rails/rails     False              NaN
# 999943     16114498     rails/rails     False              NaN
# 999944     16114498     rails/rails     False              NaN
# 999945     16114498     rails/rails     False              NaN
# 999946     16114498     rails/rails     False              NaN
# 999947     16114498     rails/rails     False              NaN
# 999948     16114498     rails/rails     False              NaN
# 999949     16114498     rails/rails     False              NaN
# 999950     16114498     rails/rails     False              NaN
# 999951     16114498     rails/rails     False              NaN
# 999952     16114498     rails/rails     False              NaN
# 999953     16114498     rails/rails     False              NaN
# 999954     16114498     rails/rails     False              NaN
#
#         gh_pull_req_num gh_lang git_merged_with git_branch  \
# 15                  NaN    ruby             NaN     master
# 16                  NaN    ruby             NaN     master
# 17                  NaN    ruby             NaN     master
# 18                  NaN    ruby             NaN     master
# 19                  NaN    ruby             NaN     master
# 20                  NaN    ruby             NaN     master
# 21                  NaN    ruby             NaN     master
# 22                  NaN    ruby             NaN     master
# 23                  NaN    ruby             NaN     master
# 24                  NaN    ruby             NaN     master
# 25                  NaN    ruby             NaN     master
# 26                  NaN    ruby             NaN     master
# 27                  NaN    ruby             NaN     master
# 28                  NaN    ruby             NaN     master
# 29                  NaN    ruby             NaN     master
# 181                 NaN    ruby             NaN     master
# 182                 NaN    ruby             NaN     master
# 183                 NaN    ruby             NaN     master
# 184                 NaN    ruby             NaN     master
# 185                 NaN    ruby             NaN     master
# 186                 NaN    ruby             NaN     master
# 187                 NaN    ruby             NaN     master
# 188                 NaN    ruby             NaN     master
# 189                 NaN    ruby             NaN     master
# 190                 NaN    ruby             NaN     master
# 191                 NaN    ruby             NaN     master
# 192                 NaN    ruby             NaN     master
# 193                 NaN    ruby             NaN     master
# 194                 NaN    ruby             NaN     master
# 195                 NaN    ruby             NaN     master
# ...                 ...     ...             ...        ...
# 999925              NaN    ruby             NaN     master
# 999926              NaN    ruby             NaN     master
# 999927              NaN    ruby             NaN     master
# 999928              NaN    ruby             NaN     master
# 999929              NaN    ruby             NaN     master
# 999930              NaN    ruby             NaN     master
# 999931              NaN    ruby             NaN     master
# 999932              NaN    ruby             NaN     master
# 999933              NaN    ruby             NaN     master
# 999934              NaN    ruby             NaN     master
# 999935              NaN    ruby             NaN     master
# 999936              NaN    ruby             NaN     master
# 999937              NaN    ruby             NaN     master
# 999938              NaN    ruby             NaN     master
# 999939              NaN    ruby             NaN     master
# 999940              NaN    ruby             NaN     master
# 999941              NaN    ruby             NaN     master
# 999942              NaN    ruby             NaN     master
# 999943              NaN    ruby             NaN     master
# 999944              NaN    ruby             NaN     master
# 999945              NaN    ruby             NaN     master
# 999946              NaN    ruby             NaN     master
# 999947              NaN    ruby             NaN     master
# 999948              NaN    ruby             NaN     master
# 999949              NaN    ruby             NaN     master
# 999950              NaN    ruby             NaN     master
# 999951              NaN    ruby             NaN     master
# 999952              NaN    ruby             NaN     master
# 999953              NaN    ruby             NaN     master
# 999954              NaN    ruby             NaN     master
#
#         gh_num_commits_in_push git_prev_commit_resolution_status  \
# 15                         NaN                       merge_found
# 16                         NaN                       merge_found
# 17                         NaN                       merge_found
# 18                         NaN                       merge_found
# 19                         NaN                       merge_found
# 20                         NaN                       merge_found
# 21                         NaN                       merge_found
# 22                         NaN                       merge_found
# 23                         NaN                       merge_found
# 24                         NaN                       merge_found
# 25                         NaN                       merge_found
# 26                         NaN                       merge_found
# 27                         NaN                       merge_found
# 28                         NaN                       merge_found
# 29                         NaN                       merge_found
# 181                        NaN                       build_found
# 182                        NaN                       build_found
# 183                        NaN                       build_found
# 184                        NaN                       build_found
# 185                        NaN                       build_found
# 186                        NaN                       build_found
# 187                        NaN                       build_found
# 188                        NaN                       build_found
# 189                        NaN                       build_found
# 190                        NaN                       build_found
# 191                        NaN                       build_found
# 192                        NaN                       build_found
# 193                        NaN                       build_found
# 194                        NaN                       build_found
# 195                        NaN                       build_found
# ...                        ...                               ...
# 999925                     2.0                       merge_found
# 999926                     2.0                       merge_found
# 999927                     2.0                       merge_found
# 999928                     2.0                       merge_found
# 999929                     2.0                       merge_found
# 999930                     2.0                       merge_found
# 999931                     2.0                       merge_found
# 999932                     2.0                       merge_found
# 999933                     2.0                       merge_found
# 999934                     2.0                       merge_found
# 999935                     2.0                       merge_found
# 999936                     2.0                       merge_found
# 999937                     2.0                       merge_found
# 999938                     2.0                       merge_found
# 999939                     2.0                       merge_found
# 999940                     2.0                       merge_found
# 999941                     2.0                       merge_found
# 999942                     2.0                       merge_found
# 999943                     2.0                       merge_found
# 999944                     2.0                       merge_found
# 999945                     2.0                       merge_found
# 999946                     2.0                       merge_found
# 999947                     2.0                       merge_found
# 999948                     2.0                       merge_found
# 999949                     2.0                       merge_found
# 999950                     2.0                       merge_found
# 999951                     2.0                       merge_found
# 999952                     2.0                       merge_found
# 999953                     2.0                       merge_found
# 999954                     2.0                       merge_found
#
#                   ...                    gh_pushed_at  gh_build_started_at  \
# 15                ...                             NaN  2011-08-29 00:13:21
# 16                ...                             NaN  2011-08-29 00:13:21
# 17                ...                             NaN  2011-08-29 00:13:21
# 18                ...                             NaN  2011-08-29 00:13:21
# 19                ...                             NaN  2011-08-29 00:13:21
# 20                ...                             NaN  2011-08-29 00:13:21
# 21                ...                             NaN  2011-08-29 00:13:21
# 22                ...                             NaN  2011-08-29 00:13:21
# 23                ...                             NaN  2011-08-29 00:13:21
# 24                ...                             NaN  2011-08-29 00:13:21
# 25                ...                             NaN  2011-08-29 00:13:21
# 26                ...                             NaN  2011-08-29 00:13:21
# 27                ...                             NaN  2011-08-29 00:13:21
# 28                ...                             NaN  2011-08-29 00:13:21
# 29                ...                             NaN  2011-08-29 00:13:21
# 181               ...                             NaN  2011-08-29 12:22:11
# 182               ...                             NaN  2011-08-29 12:22:11
# 183               ...                             NaN  2011-08-29 12:22:11
# 184               ...                             NaN  2011-08-29 12:22:11
# 185               ...                             NaN  2011-08-29 12:22:11
# 186               ...                             NaN  2011-08-29 12:22:11
# 187               ...                             NaN  2011-08-29 12:22:11
# 188               ...                             NaN  2011-08-29 12:22:11
# 189               ...                             NaN  2011-08-29 12:22:11
# 190               ...                             NaN  2011-08-29 12:22:11
# 191               ...                             NaN  2011-08-29 12:22:11
# 192               ...                             NaN  2011-08-29 12:22:11
# 193               ...                             NaN  2011-08-29 12:22:11
# 194               ...                             NaN  2011-08-29 12:22:11
# 195               ...                             NaN  2011-08-29 12:22:11
# ...               ...                             ...                  ...
# 999925            ...             2013-08-27 06:22:30  2013-12-29 20:35:24
# 999926            ...             2013-08-27 06:22:30  2013-12-29 20:35:24
# 999927            ...             2013-08-27 06:22:30  2013-12-29 20:35:24
# 999928            ...             2013-08-27 06:22:30  2013-12-29 20:35:24
# 999929            ...             2013-08-27 06:22:30  2013-12-29 20:35:24
# 999930            ...             2013-08-27 06:22:30  2013-12-29 20:35:24
# 999931            ...             2013-08-27 06:22:30  2013-12-29 20:35:24
# 999932            ...             2013-08-27 06:47:23  2013-12-29 20:35:24
# 999933            ...             2013-08-27 06:47:23  2013-12-29 20:35:24
# 999934            ...             2013-08-27 06:47:23  2013-12-29 20:35:24
# 999935            ...             2013-08-27 06:33:22  2013-12-29 20:35:24
# 999936            ...             2013-08-27 06:33:22  2013-12-29 20:35:24
# 999937            ...             2013-08-27 06:33:22  2013-12-29 20:35:24
# 999938            ...             2013-08-27 06:33:22  2013-12-29 20:35:24
# 999939            ...             2013-08-27 06:33:22  2013-12-29 20:35:24
# 999940            ...             2013-08-27 06:33:22  2013-12-29 20:35:24
# 999941            ...             2013-08-27 06:33:22  2013-12-29 20:35:24
# 999942            ...             2013-08-27 06:33:22  2013-12-29 20:35:24
# 999943            ...             2013-12-29 20:33:01  2013-12-29 20:35:24
# 999944            ...             2013-12-29 20:33:01  2013-12-29 20:35:24
# 999945            ...             2013-12-29 20:33:01  2013-12-29 20:35:24
# 999946            ...             2013-12-29 20:33:01  2013-12-29 20:35:24
# 999947            ...             2013-08-27 06:42:58  2013-12-29 20:35:24
# 999948            ...             2013-08-27 06:42:58  2013-12-29 20:35:24
# 999949            ...             2013-08-27 18:38:42  2013-12-29 20:35:24
# 999950            ...             2013-08-27 18:38:42  2013-12-29 20:35:24
# 999951            ...             2013-08-27 18:38:42  2013-12-29 20:35:24
# 999952            ...             2013-08-27 18:38:42  2013-12-29 20:35:24
# 999953            ...             2013-08-27 06:47:23  2013-12-29 20:35:24
# 999954            ...             2013-08-27 06:47:23  2013-12-29 20:35:24
#
#        tr_status                                            tr_jobs  \
# 15        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 16        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 17        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 18        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 19        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 20        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 21        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 22        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 23        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 24        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 25        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 26        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 27        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 28        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 29        failed  [106182, 106183, 106184, 106185, 106181, 10618...
# 181       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 182       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 183       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 184       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 185       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 186       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 187       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 188       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 189       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 190       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 191       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 192       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 193       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 194       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# 195       passed  [108053, 108049, 108047, 108046, 108041, 10804...
# ...          ...                                                ...
# 999925   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999926   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999927   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999928   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999929   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999930   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999931   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999932   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999933   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999934   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999935   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999936   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999937   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999938   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999939   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999940   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999941   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999942   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999943   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999944   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999945   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999946   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999947   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999948   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999949   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999950   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999951   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999952   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999953   errored  [16114499, 16114500, 16114501, 16114502, 16114...
# 999954   errored  [16114499, 16114500, 16114501, 16114502, 16114...
#
#        tr_build_number  tr_job_id tr_log_status tr_log_num_tests_ok  \
# 15                 498     106188       unknown                 NaN
# 16                 498     106187       unknown                 NaN
# 17                 498     106190       unknown                 NaN
# 18                 498     106181       unknown                 NaN
# 19                 498     106183       unknown                 NaN
# 20                 498     106189       unknown                 NaN
# 21                 498     106180       unknown                 NaN
# 22                 498     106185       unknown                 NaN
# 23                 498     106182       unknown                 NaN
# 24                 498     106178       unknown                 NaN
# 25                 498     106177       unknown                 NaN
# 26                 498     106186       unknown                 NaN
# 27                 498     106191       unknown                 NaN
# 28                 498     106184       unknown                 NaN
# 29                 498     106179       unknown                 NaN
# 181                502     108050       unknown                 NaN
# 182                502     108043       unknown                 NaN
# 183                502     108041       unknown                 NaN
# 184                502     108040       unknown                 NaN
# 185                502     108047       unknown                 NaN
# 186                502     108045       unknown                 NaN
# 187                502     108046       unknown                 NaN
# 188                502     108044       unknown                 NaN
# 189                502     108042       unknown                 NaN
# 190                502     108048       unknown                 NaN
# 191                502     108053       unknown                 NaN
# 192                502     108051       unknown                 NaN
# 193                502     108049       unknown                 NaN
# 194                502     108052       unknown                 NaN
# 195                502     108039       unknown                 NaN
# ...                ...        ...           ...                 ...
# 999925           12965   16114499        broken               629.0
# 999926           12965   16114521        broken              5786.0
# 999927           12965   16114527        broken                 NaN
# 999928           12965   16114503            ok              7626.0
# 999929           12965   16114523        broken                 NaN
# 999930           12965   16114520        broken              3769.0
# 999931           12965   16114518        broken              8995.0
# 999932           12965   16114516            ok              8100.0
# 999933           12965   16114525        broken                 NaN
# 999934           12965   16114515       unknown                 NaN
# 999935           12965   16114502            ok              7646.0
# 999936           12965   16114505        broken                23.0
# 999937           12965   16114501            ok              7672.0
# 999938           12965   16114524        broken                 NaN
# 999939           12965   16114512            ok             16359.0
# 999940           12965   16114508            ok              7646.0
# 999941           12965   16114528        broken                 NaN
# 999942           12965   16114519        broken              5132.0
# 999943           12965   16114509            ok              7626.0
# 999944           12965   16114506            ok             16359.0
# 999945           12965   16114514            ok              7646.0
# 999946           12965   16114511       unknown                 NaN
# 999947           12965   16114517        broken               191.0
# 999948           12965   16114513            ok              7672.0
# 999949           12965   16114500            ok             16357.0
# 999950           12965   16114504            ok              8100.0
# 999951           12965   16114507            ok              7672.0
# 999952           12965   16114526       unknown                 NaN
# 999953           12965   16114510            ok              8100.0
# 999954           12965   16114522       unknown                 NaN
#
#        tr_log_num_tests_failed  tr_log_num_tests_skipped
# 15                         NaN                       NaN
# 16                         NaN                       NaN
# 17                         NaN                       NaN
# 18                         NaN                       NaN
# 19                         NaN                       NaN
# 20                         NaN                       NaN
# 21                         NaN                       NaN
# 22                         NaN                       NaN
# 23                         NaN                       NaN
# 24                         NaN                       NaN
# 25                         NaN                       NaN
# 26                         NaN                       NaN
# 27                         NaN                       NaN
# 28                         NaN                       NaN
# 29                         NaN                       NaN
# 181                        NaN                       NaN
# 182                        NaN                       NaN
# 183                        NaN                       NaN
# 184                        NaN                       NaN
# 185                        NaN                       NaN
# 186                        NaN                       NaN
# 187                        NaN                       NaN
# 188                        NaN                       NaN
# 189                        NaN                       NaN
# 190                        NaN                       NaN
# 191                        NaN                       NaN
# 192                        NaN                       NaN
# 193                        NaN                       NaN
# 194                        NaN                       NaN
# 195                        NaN                       NaN
# ...                        ...                       ...
# 999925                     1.0                       0.0
# 999926                    11.0                       2.0
# 999927                     NaN                       NaN
# 999928                     0.0                       2.0
# 999929                     NaN                       NaN
# 999930                    75.0                       1.0
# 999931                    50.0                       0.0
# 999932                     0.0                      30.0
# 999933                     NaN                       NaN
# 999934                     NaN                       NaN
# 999935                     0.0                       2.0
# 999936                     1.0                       0.0
# 999937                     0.0                       2.0
# 999938                     NaN                       NaN
# 999939                     0.0                       0.0
# 999940                     0.0                       2.0
# 999941                     NaN                       NaN
# 999942                    54.0                       1.0
# 999943                     0.0                       2.0
# 999944                     0.0                       0.0
# 999945                     0.0                       2.0
# 999946                     NaN                       NaN
# 999947                     5.0                       0.0
# 999948                     0.0                       2.0
# 999949                     0.0                       2.0
# 999950                     0.0                      30.0
# 999951                     0.0                       2.0
# 999952                     NaN                       NaN
# 999953                     0.0                      30.0
# 999954                     0.0                       NaN
#
# [83358 rows x 38 columns]

# %%
#df_statusFail = df_java.loc[df_java['tr_status']=='failed'] # Filtra apenas as bulds quebradas
df_ruby

# %% [markdown]
# Onde: num_commitsTPP significa o número total de commits por projeto, obtido após agrupamento da amostra por gh_project_name e somando git_num_commits;
#
#
# tempoDP significa o tempo total de duração de cada projeto em dias, obtido após agrupamento da amostra por gh_project_name
#
# e
#
#
# diminuindo a data máxima da data mínima extraída de gh_first_commit_created_at no grupo;
#
#
# MediaPartPP significa a média de participantes por projeto, obtido após agrupamento da amostra por gh_project_name,
#
#
#
# somando gh_team_size
#
#
# e dividindo pelo número de builds em cada grupo,
#
# tendo em vista que gh_team_size tem pequenas variações entre builds ao longo do projeto.
#
# Para cada linguagem obtemos a TxCommitsPP e realizamos o teste de normalidade de Shapiro-Wilk e plotamos o gráfico quantil-quantil (QQ). Como as duas distribuições se desviaram da distribuição normal de forma significante, observamos no gráfico QQ que as duas amostras possuem forma de distribuição semelhante confirmada pelo teste de variância. Assim, para verificar se existe diferença estatística significante entre as duas distribuições, optamos por usar o teste não paramétrico U de Mann-Whitney. Os gráficos QQ podem ser vistos nas Figuras 1 e 2, abaixo.
