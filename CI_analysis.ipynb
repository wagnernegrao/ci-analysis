# %%
import pandas as pd

# %%
file = 'travistorrent_11_1_2017.csv'
chunksize = 1000000

# %%
for dataset in pd.read_csv(file, engine='c', chunksize=chunksize):
    process(dataset)
# Out:
# /home/wagner/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3,6,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ------------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-3-92e1eb900a9e> in <module>()
#       1 for dataset in pd.read_csv(file, engine='c', chunksize=chunksize):
# ----> 2     process(dataset)
#
# NameError: name 'process' is not defined

# %%
#dataset = pd.read_csv('travistorrent_11_1_2017.csv',sep=',', engine='c', nrows=3000000, na_values=str, keep_default_na = bool, encoding='utf-8')
# nrows=1000000
'''
Signature:
    sep - separa por virgula
    nrows - limite de linhas lidas
    encoding - tipo de caracter
    engine - Mecanismo do analisador
    na_values - procura os padrões na|nan como str
    keep_default_na - define como nan os padroes econtrados em na_values
    
'''
# Out:
# '\nSignature:\n    sep - separa por virgula\n    nrows - limite de linhas lidas\n    encoding - tipo de caracter\n    engine - Mecanismo do analisador\n    na_values - procura os padrões na|nan como str\n    keep_default_na - define como nan os padroes econtrados em na_values\n    \n'

# %% [markdown]
# <font size=4/>
#    * Elimia as colunas não utilizadas

# %%
# Eliminando colunas
dataset.drop([  'gh_diff_files_added',
                'gh_commits_in_push',
                'gh_diff_files_deleted',
                'gh_diff_files_modified',
                'gh_diff_tests_added',
                'gh_diff_tests_deleted',
                'gh_diff_src_files',
                'gh_diff_doc_files',
                'gh_diff_other_files',
                'gh_sloc',
                'gh_test_lines_per_kloc',
                'gh_test_cases_per_kloc',
            
                'tr_duration',
                'tr_log_lan',
                'tr_log_num_tests_run',
                'tr_log_setup_time',
                'tr_log_analyzer',
                'tr_log_frameworks',
                'tr_log_bool_tests_ran',
                'tr_log_bool_tests_failed',
                'tr_log_tests_failed',
                'tr_log_testduration',
                'tr_log_buildduration'], axis=1, inplace=True)

# %%
def categorizaPush(valor):
    if(valor < 20):
        return 0

# %% [markdown]
# <font size=4/>
#    * Filtra a linguagem e o projeto

# %%
df_ruby = dataset.loc[dataset['gh_lang']=='ruby'] # Filtro apenas linguagem ruby

df_ruby = df_java.loc[df_java['gh_project_name']=='rails/rails'] # Filtro penas o projeto SonarSource
# Out:
#         tr_build_id     gh_project_name  gh_is_pr     gh_pr_created_at  \
# 0            106060         rails/rails     False                  NaN
# 1            106060         rails/rails     False                  NaN
# 2            106060         rails/rails     False                  NaN
# 3            106060         rails/rails     False                  NaN
# 4            106060         rails/rails     False                  NaN
# 5            106060         rails/rails     False                  NaN
# 6            106060         rails/rails     False                  NaN
# 7            106060         rails/rails     False                  NaN
# 8            106060         rails/rails     False                  NaN
# 9            106060         rails/rails     False                  NaN
# 10           106060         rails/rails     False                  NaN
# 11           106060         rails/rails     False                  NaN
# 12           106060         rails/rails     False                  NaN
# 13           106060         rails/rails     False                  NaN
# 14           106060         rails/rails     False                  NaN
# 15           106176         rails/rails     False                  NaN
# 16           106176         rails/rails     False                  NaN
# 17           106176         rails/rails     False                  NaN
# 18           106176         rails/rails     False                  NaN
# 19           106176         rails/rails     False                  NaN
# 20           106176         rails/rails     False                  NaN
# 21           106176         rails/rails     False                  NaN
# 22           106176         rails/rails     False                  NaN
# 23           106176         rails/rails     False                  NaN
# 24           106176         rails/rails     False                  NaN
# 25           106176         rails/rails     False                  NaN
# 26           106176         rails/rails     False                  NaN
# 27           106176         rails/rails     False                  NaN
# 28           106176         rails/rails     False                  NaN
# 29           106176         rails/rails     False                  NaN
# ...             ...                 ...       ...                  ...
# 999969     16114750     RubyMoney/money     False                  NaN
# 999970     16114750     RubyMoney/money     False                  NaN
# 999971     16114786     BBC-News/wraith     False                  NaN
# 999972     16114786     BBC-News/wraith     False                  NaN
# 999973     16114789     BBC-News/wraith      True  2013-12-29 19:18:36
# 999974     16114789     BBC-News/wraith      True  2013-12-29 19:18:36
# 999975     16114822     RubyMoney/money     False                  NaN
# 999976     16114822     RubyMoney/money     False                  NaN
# 999977     16114822     RubyMoney/money     False                  NaN
# 999978     16114875  RubyMoney/monetize     False                  NaN
# 999979     16114875  RubyMoney/monetize     False                  NaN
# 999980     16114875  RubyMoney/monetize     False                  NaN
# 999981     16114909  RubyMoney/monetize     False                  NaN
# 999982     16114909  RubyMoney/monetize     False                  NaN
# 999983     16114909  RubyMoney/monetize     False                  NaN
# 999984     16114927      cantino/huginn     False                  NaN
# 999985     16114929      cantino/huginn      True  2013-12-27 17:02:44
# 999986     16115381     git/git-scm.com     False                  NaN
# 999987     16115418  sup-heliotrope/sup     False                  NaN
# 999988     16115418  sup-heliotrope/sup     False                  NaN
# 999989     16115430     BBC-News/wraith     False                  NaN
# 999990     16115430     BBC-News/wraith     False                  NaN
# 999991     16115433     BBC-News/wraith      True  2013-12-29 19:18:36
# 999992     16115433     BBC-News/wraith      True  2013-12-29 19:18:36
# 999994     16115792   rspec/rspec-rails     False                  NaN
# 999995     16115792   rspec/rspec-rails     False                  NaN
# 999996     16115792   rspec/rspec-rails     False                  NaN
# 999997     16115792   rspec/rspec-rails     False                  NaN
# 999998     16115792   rspec/rspec-rails     False                  NaN
# 999999     16115792   rspec/rspec-rails     False                  NaN
#
#         gh_pull_req_num gh_lang git_merged_with  \
# 0                   NaN    ruby             NaN
# 1                   NaN    ruby             NaN
# 2                   NaN    ruby             NaN
# 3                   NaN    ruby             NaN
# 4                   NaN    ruby             NaN
# 5                   NaN    ruby             NaN
# 6                   NaN    ruby             NaN
# 7                   NaN    ruby             NaN
# 8                   NaN    ruby             NaN
# 9                   NaN    ruby             NaN
# 10                  NaN    ruby             NaN
# 11                  NaN    ruby             NaN
# 12                  NaN    ruby             NaN
# 13                  NaN    ruby             NaN
# 14                  NaN    ruby             NaN
# 15                  NaN    ruby             NaN
# 16                  NaN    ruby             NaN
# 17                  NaN    ruby             NaN
# 18                  NaN    ruby             NaN
# 19                  NaN    ruby             NaN
# 20                  NaN    ruby             NaN
# 21                  NaN    ruby             NaN
# 22                  NaN    ruby             NaN
# 23                  NaN    ruby             NaN
# 24                  NaN    ruby             NaN
# 25                  NaN    ruby             NaN
# 26                  NaN    ruby             NaN
# 27                  NaN    ruby             NaN
# 28                  NaN    ruby             NaN
# 29                  NaN    ruby             NaN
# ...                 ...     ...             ...
# 999969              NaN    ruby             NaN
# 999970              NaN    ruby             NaN
# 999971              NaN    ruby             NaN
# 999972              NaN    ruby             NaN
# 999973             78.0    ruby    merge_button
# 999974             78.0    ruby    merge_button
# 999975              NaN    ruby             NaN
# 999976              NaN    ruby             NaN
# 999977              NaN    ruby             NaN
# 999978              NaN    ruby             NaN
# 999979              NaN    ruby             NaN
# 999980              NaN    ruby             NaN
# 999981              NaN    ruby             NaN
# 999982              NaN    ruby             NaN
# 999983              NaN    ruby             NaN
# 999984              NaN    ruby             NaN
# 999985            116.0    ruby    merge_button
# 999986              NaN    ruby             NaN
# 999987              NaN    ruby             NaN
# 999988              NaN    ruby             NaN
# 999989              NaN    ruby             NaN
# 999990              NaN    ruby             NaN
# 999991             78.0    ruby    merge_button
# 999992             78.0    ruby    merge_button
# 999994              NaN    ruby             NaN
# 999995              NaN    ruby             NaN
# 999996              NaN    ruby             NaN
# 999997              NaN    ruby             NaN
# 999998              NaN    ruby             NaN
# 999999              NaN    ruby             NaN
#
#                                 git_branch  gh_num_commits_in_push  \
# 0                               3-1-stable                     NaN
# 1                               3-1-stable                     NaN
# 2                               3-1-stable                     NaN
# 3                               3-1-stable                     NaN
# 4                               3-1-stable                     NaN
# 5                               3-1-stable                     NaN
# 6                               3-1-stable                     NaN
# 7                               3-1-stable                     NaN
# 8                               3-1-stable                     NaN
# 9                               3-1-stable                     NaN
# 10                              3-1-stable                     NaN
# 11                              3-1-stable                     NaN
# 12                              3-1-stable                     NaN
# 13                              3-1-stable                     NaN
# 14                              3-1-stable                     NaN
# 15                                  master                     NaN
# 16                                  master                     NaN
# 17                                  master                     NaN
# 18                                  master                     NaN
# 19                                  master                     NaN
# 20                                  master                     NaN
# 21                                  master                     NaN
# 22                                  master                     NaN
# 23                                  master                     NaN
# 24                                  master                     NaN
# 25                                  master                     NaN
# 26                                  master                     NaN
# 27                                  master                     NaN
# 28                                  master                     NaN
# 29                                  master                     NaN
# ...                                    ...                     ...
# 999969                              master                     1.0
# 999970                              master                     1.0
# 999971                   componentise-code                     1.0
# 999972                   componentise-code                     1.0
# 999973                              master                     1.0
# 999974                              master                     1.0
# 999975                              master                     1.0
# 999976                              master                     1.0
# 999977                              master                     1.0
# 999978                              master                     1.0
# 999979                              master                     1.0
# 999980                              master                     1.0
# 999981                              master                     1.0
# 999982                              master                     1.0
# 999983                              master                     1.0
# 999984                    do_not_symbolize                    12.0
# 999985                              master                    12.0
# 999986                              master                     NaN
# 999987                             develop                     1.0
# 999988                             develop                     1.0
# 999989                   componentise-code                     3.0
# 999990                   componentise-code                     3.0
# 999991                              master                     3.0
# 999992                              master                     3.0
# 999994  capybara_dsl_controller_specs_2_99                     2.0
# 999995  capybara_dsl_controller_specs_2_99                     2.0
# 999996  capybara_dsl_controller_specs_2_99                     2.0
# 999997  capybara_dsl_controller_specs_2_99                     2.0
# 999998  capybara_dsl_controller_specs_2_99                     2.0
# 999999  capybara_dsl_controller_specs_2_99                     2.0
#
#        git_prev_commit_resolution_status            ...             \
# 0                            build_found            ...
# 1                            build_found            ...
# 2                            build_found            ...
# 3                            build_found            ...
# 4                            build_found            ...
# 5                            build_found            ...
# 6                            build_found            ...
# 7                            build_found            ...
# 8                            build_found            ...
# 9                            build_found            ...
# 10                           build_found            ...
# 11                           build_found            ...
# 12                           build_found            ...
# 13                           build_found            ...
# 14                           build_found            ...
# 15                           merge_found            ...
# 16                           merge_found            ...
# 17                           merge_found            ...
# 18                           merge_found            ...
# 19                           merge_found            ...
# 20                           merge_found            ...
# 21                           merge_found            ...
# 22                           merge_found            ...
# 23                           merge_found            ...
# 24                           merge_found            ...
# 25                           merge_found            ...
# 26                           merge_found            ...
# 27                           merge_found            ...
# 28                           merge_found            ...
# 29                           merge_found            ...
# ...                                  ...            ...
# 999969                       build_found            ...
# 999970                       build_found            ...
# 999971                       build_found            ...
# 999972                       build_found            ...
# 999973                       build_found            ...
# 999974                       build_found            ...
# 999975                       build_found            ...
# 999976                       build_found            ...
# 999977                       build_found            ...
# 999978                       build_found            ...
# 999979                       build_found            ...
# 999980                       build_found            ...
# 999981                       build_found            ...
# 999982                       build_found            ...
# 999983                       build_found            ...
# 999984                       merge_found            ...
# 999985                       merge_found            ...
# 999986                       merge_found            ...
# 999987                       build_found            ...
# 999988                       build_found            ...
# 999989                       build_found            ...
# 999990                       build_found            ...
# 999991                       build_found            ...
# 999992                       build_found            ...
# 999994                       merge_found            ...
# 999995                       merge_found            ...
# 999996                       merge_found            ...
# 999997                       merge_found            ...
# 999998                       merge_found            ...
# 999999                       merge_found            ...
#
#                gh_pushed_at  gh_build_started_at tr_status  \
# 0                       NaN  2011-08-29 00:25:49    passed
# 1                       NaN  2011-08-29 00:25:49    passed
# 2                       NaN  2011-08-29 00:25:49    passed
# 3                       NaN  2011-08-29 00:25:49    passed
# 4                       NaN  2011-08-29 00:25:49    passed
# 5                       NaN  2011-08-29 00:25:49    passed
# 6                       NaN  2011-08-29 00:25:49    passed
# 7                       NaN  2011-08-29 00:25:49    passed
# 8                       NaN  2011-08-29 00:25:49    passed
# 9                       NaN  2011-08-29 00:25:49    passed
# 10                      NaN  2011-08-29 00:25:49    passed
# 11                      NaN  2011-08-29 00:25:49    passed
# 12                      NaN  2011-08-29 00:25:49    passed
# 13                      NaN  2011-08-29 00:25:49    passed
# 14                      NaN  2011-08-29 00:25:49    passed
# 15                      NaN  2011-08-29 00:13:21    failed
# 16                      NaN  2011-08-29 00:13:21    failed
# 17                      NaN  2011-08-29 00:13:21    failed
# 18                      NaN  2011-08-29 00:13:21    failed
# 19                      NaN  2011-08-29 00:13:21    failed
# 20                      NaN  2011-08-29 00:13:21    failed
# 21                      NaN  2011-08-29 00:13:21    failed
# 22                      NaN  2011-08-29 00:13:21    failed
# 23                      NaN  2011-08-29 00:13:21    failed
# 24                      NaN  2011-08-29 00:13:21    failed
# 25                      NaN  2011-08-29 00:13:21    failed
# 26                      NaN  2011-08-29 00:13:21    failed
[106182, 106183, 106184, 106185, 106181, 10618...             498
# 28      [106182, 106183, 106184, 106185, 106181, 10618...             498
# 29      [106182, 106183, 106184, 106185, 106181, 10618...             498
# ...                                                   ...             ...
# 999969                     [16114751, 16114752, 16114753]             462
# 999970                     [16114751, 16114752, 16114753]             462
# 999971                               [16114787, 16114788]              56
# 999972                               [16114787, 16114788]              56
# 999973                               [16114790, 16114791]              57
# 999974                               [16114790, 16114791]              57
# 999975                     [16114823, 16114824, 16114825]             463
# 999976                     [16114823, 16114824, 16114825]             463
# 999977                     [16114823, 16114824, 16114825]             463
# 999978                     [16114876, 16114877, 16114878]               6
# 999979                     [16114876, 16114877, 16114878]               6
# 999980                     [16114876, 16114877, 16114878]               6
# 999981                     [16114910, 16114911, 16114912]               7
# 999982                     [16114910, 16114911, 16114912]               7
# 999983                     [16114910, 16114911, 16114912]               7
# 999984                                         [16114928]             251
# 999985                                         [16114930]             252
# 999986                                         [16115382]             278
# 999987                               [16115419, 16115420]             399
# 999988                               [16115419, 16115420]             399
# 999989                               [16115431, 16115432]              58
# 999990                               [16115431, 16115432]              58
# 999991                               [16115434, 16115435]              59
# 999992                               [16115434, 16115435]              59
# 999994  [16115793, 16115794, 16115795, 16115796, 16115...             905
# 999995  [16115793, 16115794, 16115795, 16115796, 16115...             905
# 999996  [16115793, 16115794, 16115795, 16115796, 16115...             905
# 999997  [16115793, 16115794, 16115795, 16115796, 16115...             905
# 999998  [16115793, 16115794, 16115795, 16115796, 16115...             905
# 999999  [16115793, 16115794, 16115795, 16115796, 16115...             905
#
#         tr_job_id tr_log_status tr_log_num_tests_ok tr_log_num_tests_failed  \
# 0          106065       unknown                 NaN                     NaN
# 1          106063       unknown                 NaN                     NaN
# 2          106062       unknown                 NaN                     NaN
# 3          106066       unknown                 NaN                     NaN
# 4          106071       unknown                 NaN                     NaN
# 5          106074       unknown                 NaN                     NaN
# 6          106064       unknown                 NaN                     NaN
# 7          106075       unknown                 NaN                     NaN
# 8          106072       unknown                 NaN                     NaN
# 9          106073       unknown                 NaN                     NaN
# 10         106069       unknown                 NaN                     NaN
# 11         106070       unknown                 NaN                     NaN
# 12         106068       unknown                 NaN                     NaN
# 13         106061       unknown                 NaN                     NaN
# 14         106067       unknown                 NaN                     NaN
# 15         106188       unknown                 NaN                     NaN
# 16         106187       unknown                 NaN                     NaN
# 17         106190       unknown                 NaN                     NaN
# 18         106181       unknown                 NaN                     NaN
# 19         106183       unknown                 NaN                     NaN
# 20         106189       unknown                 NaN                     NaN
# 21         106180       unknown                 NaN                     NaN
# 22         106185       unknown                 NaN                     NaN
# 23         106182       unknown                 NaN                     NaN
# 24         106178       unknown                 NaN                     NaN
# 25         106177       unknown                 NaN                     NaN
# 26         106186       unknown                 NaN                     NaN
# 27         106191       unknown                 NaN                     NaN
# 28         106184       unknown                 NaN                     NaN
# 29         106179       unknown                 NaN                     NaN
# ...           ...           ...                 ...                     ...
# 999969   16114753            ok               341.0                     0.0
# 999970   16114752            ok               341.0                     0.0
# 999971   16114788        broken                 NaN                     NaN
# 999972   16114787        broken                 NaN                     NaN
# 999973   16114790        broken                 NaN                     NaN
# 999974   16114791        broken                 NaN                     NaN
# 999975   16114825            ok               341.0                     0.0
# 999976   16114823            ok               341.0                     0.0
# 999977   16114824            ok               341.0                     0.0
# 999978   16114878            ok                50.0                     0.0
# 999979   16114877            ok                50.0                     0.0
# 999980   16114876            ok                50.0                     0.0
# 999981   16114911            ok                50.0                     0.0
# 999982   16114912            ok                50.0                     0.0
# 999983   16114910            ok                50.0                     0.0
# 999984   16114928            ok               197.0                     0.0
# 999985   16114930            ok               197.0                     0.0
# 999986   16115382            ok                 NaN                     NaN
# 999987   16115419            ok                 NaN                     NaN
# 999988   16115420            ok                 NaN                     NaN
# 999989   16115431            ok                 NaN                     NaN
# 999990   16115432            ok                 NaN                     NaN
# 999991   16115435            ok                 NaN                     NaN
# 999992   16115434            ok                 NaN                     NaN
# 999994   16115820            ok                 NaN                     NaN
# 999995   16115836            ok                 NaN                     NaN
# 999996   16115804            ok                 NaN                     NaN
# 999997   16115849            ok                 NaN                     NaN
# 999998   16115810            ok                 NaN                     NaN
# 999999   16115834            ok                 NaN                     NaN
#
#         tr_log_num_tests_skipped
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
# ...                          ...
# 999969                       0.0
# 999970                       0.0
# 999971                       NaN
# 999972                       NaN
# 999973                       NaN
# 999974                       NaN
# 999975                       0.0
# 999976                       0.0
# 999977                       0.0
# 999978                       0.0
# 999979                       0.0
# 999980                       0.0
# 999981                       0.0
# 999982                       0.0
# 999983                       0.0
# 999984                       0.0
# 999985                       0.0
# 999986                       NaN
# 999987                       NaN
# 999988                       NaN
# 999989                       NaN
# 999990                       NaN
# 999991                       NaN
# 999992                       NaN
# 999994                       NaN
# 999995                       NaN
# 999996                       NaN
# 999997                       NaN
# 999998                       NaN
# 999999                       NaN
#
# [928933 rows x 38 columns]

# %%
#df_statusFail = df_java.loc[df_java['tr_status']=='failed'] # Filtra apenas as bulds quebradas
df_ruby

# %%
df_ruby.loc[df_ruby['gh_num_commits_in_push'] > 0].head()
# Out:
#       tr_build_id gh_project_name  gh_is_pr gh_pr_created_at  gh_pull_req_num  \
# 5370       131888  afeld/magickly     False              NaN              NaN
# 5371       131888  afeld/magickly     False              NaN              NaN
# 5389       131947  afeld/magickly     False              NaN              NaN
# 5390       131947  afeld/magickly     False              NaN              NaN
# 7983       142596  afeld/magickly     False              NaN              NaN
#
#      gh_lang git_merged_with git_branch  gh_num_commits_in_push  \
# 5370    ruby             NaN      cedar                     9.0
# 5371    ruby             NaN      cedar                     9.0
# 5389    ruby             NaN      cedar                     9.0
# 5390    ruby             NaN      cedar                     9.0
# 7983    ruby             NaN      cedar                     9.0
#
#      git_prev_commit_resolution_status            ...             \
# 5370                       build_found            ...
# 5371                       build_found            ...
# 5389                       merge_found            ...
# 5390                       merge_found            ...
# 7983                       merge_found            ...
#
#              gh_pushed_at  gh_build_started_at tr_status           tr_jobs  \
# 5370  2013-02-27 09:47:58  2011-09-05 19:10:24    passed  [131889, 131890]
# 5371  2013-02-27 09:47:58  2011-09-05 19:10:24    passed  [131889, 131890]
# 5389  2013-02-27 09:47:58  2011-09-05 19:16:14    passed  [131949, 131948]
# 5390  2013-02-27 09:47:58  2011-09-05 19:16:14    passed  [131949, 131948]
